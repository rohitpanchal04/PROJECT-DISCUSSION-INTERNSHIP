# %%
# IMPORTING LIBRARIES
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# Importing Dataset
STMarks=pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/Grades/Grades.csv')
STMarks
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 0    CS-97001     B-     D+     C-         C     C-     D+      D     C-
# 1    CS-97002      A      D     D+         D     B-      C      D      A
# 2    CS-97003      A      B      A        B-     B+      A     B-     B+
# 3    CS-97004      D     C+     D+         D      D     A-     D+     C-
# 4    CS-97005     A-     A-     A-        B+      A      A     A-     B+
# ..        ...    ...    ...    ...       ...    ...    ...    ...    ...
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# ...

# %%
# As We are seeing that our values are in alphabets and looks like our data is object type.

# %%
# Checking Shape
STMarks.shape
# Out:
# (571, 43)

# %%
# We get to know that in our dataset there is 571 Rows and 43 Columns

# %%
# Lets Visualize the null values
sns.heatmap(STMarks.isnull(),cmap='Blues')
plt.show()

# %%
# By checking the heatmap we get to know that there is very much null values and in approx column the Null Values are present

# %%
STMarks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 43 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Seat No.   571 non-null    object
#  1   PH-121     571 non-null    object
#  2   HS-101     571 non-null    object
#  3   CY-105     570 non-null    object
#  4   HS-105/12  570 non-null    object
#  5   MT-111     569 non-null    object
#  6   CS-105     571 non-null    object
#  7   CS-106     569 non-null    object
#  8   EL-102     569 non-null    object
#  9   EE-119     569 non-null    object
#  10  ME-107     569 non-null    object
#  11  CS-107     569 non-null    object
#  12  HS-205/20  566 non-null    object
#  13  MT-222     566 non-null    object
#  14  EE-222     564 non-null    object
#  15  MT-224     564 non-null    object
#  16  CS-210     564 non-null    object
#  17  CS-211     566 non-null    object
#  18  CS-203     566 non-null    object
# ...

# %%
# There are 571 rows in the dataset and there are 2 types of datatype - Object and Float
# Float Datatype are target Variable
# Object Datatype are independent Variable

# %%
STMarks.isnull().sum()
# Out:
# Seat No.      0
# PH-121        0
# HS-101        0
# CY-105        1
# HS-105/12     1
# MT-111        2
# CS-105        0
# CS-106        2
# EL-102        2
# EE-119        2
# ME-107        2
# CS-107        2
# HS-205/20     5
# MT-222        5
# EE-222        7
# MT-224        7
# CS-210        7
# CS-211        5
# CS-203        5
# CS-214        6
# EE-217        6
# CS-212        6
# CS-215        6
# MT-331        9
# EF-303       10
# HS-304       10
# CS-301       10
# CS-302       10
# TC-383       10
# MT-442       10
# EL-332        9
# CS-318        9
# CS-306        9
# CS-312       10
# CS-317       12
# CS-403       12
# CS-421       12
# CS-406       85
# CS-414       13
# CS-419       13
# CS-423       14
# CS-412       79
# CGPA          0
# dtype: int64

# %%
# There is so much Null Values presnet in our dataset

# %%
#Lets fill the Null Values in each columns by Mode method

for col in STMarks.columns:
    STMarks[col].fillna(STMarks[col].mode()[0], inplace=True)

STMarks.head()
# Out:
#    Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119  \
# 0  CS-97001     B-     D+     C-         C     C-     D+      D     C-     B-
# 1  CS-97002      A      D     D+         D     B-      C      D      A     D+
# 2  CS-97003      A      B      A        B-     B+      A     B-     B+     A-
# 3  CS-97004      D     C+     D+         D      D     A-     D+     C-      D
# 4  CS-97005     A-     A-     A-        B+      A      A     A-     B+      A
#
#    ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423 CS-412   CGPA
# 0  ...     C-     C-     C-     C-     A-      A     C-      B     A-  2.205
# 1  ...     D+      D      C      D     A-     B-      C      C      B  2.008
# 2  ...      B      B      A      C      A      A      A     A-      A  3.608
# 3  ...     D+      C     D+     C-     B-      B     C+     C+     C+  1.906
# 4  ...     B-     B+     B+     B-     A-      A     A-     A-      A  3.448
#
# [5 rows x 43 columns]

# %%
# Looks that we have successfully filled the Null Values

STMarks.isnull().sum()
# Out:
# Seat No.     0
# PH-121       0
# HS-101       0
# CY-105       0
# HS-105/12    0
# MT-111       0
# CS-105       0
# CS-106       0
# EL-102       0
# EE-119       0
# ME-107       0
# CS-107       0
# HS-205/20    0
# MT-222       0
# EE-222       0
# MT-224       0
# CS-210       0
# CS-211       0
# CS-203       0
# CS-214       0
# EE-217       0
# CS-212       0
# CS-215       0
# MT-331       0
# EF-303       0
# HS-304       0
# CS-301       0
# CS-302       0
# TC-383       0
# MT-442       0
# EL-332       0
# CS-318       0
# CS-306       0
# CS-312       0
# CS-317       0
# CS-403       0
# CS-421       0
# CS-406       0
# CS-414       0
# CS-419       0
# CS-423       0
# CS-412       0
# CGPA         0
# dtype: int64

# %%
# Lets Visualize again Null Values
sns.heatmap(STMarks.isnull())
plt.show()

# %%
# Seprating the Independent Variable and Target Variable

x = STMarks.iloc[:,1:-1]
y = STMarks['CGPA']

# %%
x.columns
# Out:
# Index(['PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111', 'CS-105', 'CS-106',
#        'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20', 'MT-222', 'EE-222',
#        'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214', 'EE-217', 'CS-212',
#        'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301', 'CS-302', 'TC-383',
#        'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312', 'CS-317', 'CS-403',
#        'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423', 'CS-412'],
#       dtype='object')

# %%
x.shape
# Out:
# (571, 41)

# %%
# Checking the Unique Values in Each Columns

unique_values = x.apply(lambda x: x.unique().tolist())
print(unique_values)
print('\n')
# Out:
# PH-121         [B-, A, D, A-, B+, B, C+, C, C-, D+, WU, A+, F]
# HS-101             [D+, D, B, C+, A-, B-, C-, B+, C, A, A+, F]
# CY-105         [C-, D+, A, A-, B, C+, B+, B-, C, D, WU, A+, F]
# HS-105/12      [C, D, B-, B+, D+, B, C-, C+, A-, A, WU, A+, F]
# MT-111         [C-, B-, B+, D, A, C+, A-, C, B, D+, A+, F, WU]
# CS-105                [D+, C, A, A-, B, B-, B+, C+, C-, A+, D]
# CS-106         [D, B-, D+, A-, C+, A, C-, C, B, B+, A+, F, WU]
# EL-102         [C-, A, B+, B, A-, B-, C, C+, D+, D, A+, WU, F]
# EE-119            [B-, D+, A-, D, A, B+, B, C-, C+, C, WU, A+]
# ME-107         [C-, D, A-, C+, B+, A, D+, C, B, B-, WU, F, A+]
# CS-107       [C-, B+, B-, D, C, A-, C+, D+, B, A, A+, I, WU...
# HS-205/20      [B+, C+, A-, B, A, B-, D, WU, A+, C, D+, C-, F]
# MT-222       [D, B-, A, D+, C, B+, A-, B, C+, C-, WU, F, A+...
# EE-222          [A-, C-, A, B-, B+, C+, D+, B, C, W, A+, D, F]
# MT-224       [B-, D+, A, D, A-, C-, C, B+, C+, B, A+, WU, W...
# ...

# %%
# Looks like there is exact similar values in each columns 
# These Values indicates the Grades of Students

# %%
# Number of Unique Values

x.nunique()
# Out:
# PH-121       13
# HS-101       12
# CY-105       13
# HS-105/12    13
# MT-111       13
# CS-105       11
# CS-106       13
# EL-102       13
# EE-119       12
# ME-107       13
# CS-107       14
# HS-205/20    13
# MT-222       14
# EE-222       13
# MT-224       14
# CS-210       14
# CS-211       14
# CS-203       13
# CS-214       13
# EE-217       13
# CS-212       12
# CS-215       14
# MT-331       12
# EF-303       12
# HS-304       14
# CS-301       12
# CS-302       11
# TC-383       12
# MT-442       12
# EL-332       13
# CS-318       14
# CS-306       13
# CS-312       14
# CS-317       12
# CS-403       11
# CS-421       13
# CS-406       14
# CS-414       13
# CS-419       12
# CS-423       12
# CS-412       13
# dtype: int64

# %%
# Making Categorical Values into Numerical Values 
# Using LAbel Encoder Method

# %%
from sklearn.preprocessing import LabelEncoder


#Initialize a LabelEncoder
le = LabelEncoder()

# Loop through each categorical column and apply the LabelEncoder
for col in x.columns:
    x[col] = le.fit_transform(x[col])

x.head(30)
# Out:
#     PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  EL-102  EE-119  \
# 0        5      10       8          6       8      10       9       8       5
# 1        0       9      10          9       5       6       9       0      10
# 2        0       3       0          5       4       0       5       4       2
# 3        9       7      10          9       9       2      10       8       9
# 4        2       2       2          4       0       0       2       4       0
# 5        0       5       3         10       7       2       7       3       4
# 6        5       8       2          9       2       3       0       4       2
# 7        4       4       7          6       6       2       8       2       3
# 8        2       6       2         10       3       2       2       2       4
# 9        0       3       7          3       3       2       6       5       2
# 10       2       5       4          8       8       5       7       5       0
# ...

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 41 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   PH-121     571 non-null    int32
#  1   HS-101     571 non-null    int32
#  2   CY-105     571 non-null    int32
#  3   HS-105/12  571 non-null    int32
#  4   MT-111     571 non-null    int32
#  5   CS-105     571 non-null    int32
#  6   CS-106     571 non-null    int32
#  7   EL-102     571 non-null    int32
#  8   EE-119     571 non-null    int32
#  9   ME-107     571 non-null    int32
#  10  CS-107     571 non-null    int32
#  11  HS-205/20  571 non-null    int32
#  12  MT-222     571 non-null    int32
#  13  EE-222     571 non-null    int32
#  14  MT-224     571 non-null    int32
#  15  CS-210     571 non-null    int32
#  16  CS-211     571 non-null    int32
#  17  CS-203     571 non-null    int32
#  18  CS-214     571 non-null    int32
#  19  EE-217     571 non-null    int32
# ...

# %%
# We have converted Object Datatype into Numerical Values

# %%
# Statistics of Dataset 

x.describe()
# Out:
#            PH-121      HS-101      CY-105   HS-105/12      MT-111      CS-105  \
# count  571.000000  571.000000  571.000000  571.000000  571.000000  571.000000
# mean     3.781086    5.071804    2.898424    4.241681    3.896673    2.838879
# std      3.046895    2.785317    2.964737    3.200507    2.988546    2.696709
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      2.000000    3.000000    0.000000    2.000000    2.000000    0.000000
# 50%      3.000000    5.000000    2.000000    4.000000    4.000000    2.000000
# 75%      6.000000    7.000000    4.500000    7.000000    6.000000    4.000000
# max     12.000000   11.000000   12.000000   12.000000   12.000000   10.000000
#
#            CS-106      EL-102      EE-119      ME-107  ...      CS-306  \
# count  571.000000  571.000000  571.000000  571.000000  ...  571.000000
# mean     4.122592    3.959720    3.886165    4.779335  ...    4.106830
# ...

# %%
# The count of all columns is 571 rows
# Mean and Median of dataset Columns are exact Similar so we can say that it is Normally Distributed
# There is difference b/w Maximum and Minimum and looks there is outliers present in the dataset

# %%
# Checking Outliers in Columns using Box Plot

# %%
plt.figure(figsize=(40,50), facecolor='powderblue')
plotnumber = 1
for i, col in enumerate(x.columns):
    if plotnumber < 43:
        ax = plt.subplot(11, 4, plotnumber)
        sns.boxplot(data=x, x=col, palette="Set2", width=0.5, whis=(5, 90))
        plt.xlabel(col, fontsize=20)
        plotnumber += 1
plt.show()

# %%
# Looks Like there is little Outliers Present in the dataset but we should not delete the outliers. 
# because it is a real dataset and if we remove outliers we will loose lots of our data.

# %%
# Lets check Skewness

x.skew()
# Out:
# PH-121       0.549104
# HS-101       0.053303
# CY-105       0.982144
# HS-105/12    0.324183
# MT-111       0.484906
# CS-105       0.930769
# CS-106       0.639845
# EL-102       0.501161
# EE-119       0.574880
# ME-107       0.108385
# CS-107       0.414846
# HS-205/20    0.897186
# MT-222       0.193993
# EE-222       0.759105
# MT-224       0.430480
# CS-210       0.723967
# CS-211       0.116085
# CS-203       0.274205
# CS-214       0.013129
# EE-217       0.724325
# CS-212       0.414872
# CS-215       0.163631
# MT-331       0.627721
# EF-303       0.383655
# HS-304       0.544843
# CS-301       0.415084
# CS-302       0.601788
# TC-383       0.331652
# MT-442       0.869952
# EL-332       0.459160
# CS-318       0.356504
# CS-306       0.424753
# CS-312       0.442525
# CS-317       0.140692
# CS-403       0.618339
# CS-421       0.179508
# CS-406       1.522703
# CS-414       1.292931
# CS-419       0.506748
# CS-423       0.526550
# CS-412       1.329362
# ...

# %%
# Looks like skewness is positive

# %%
# Lets Check Correlation 

plt.figure(figsize=(30,15),facecolor='powderblue')
sns.heatmap(x.corr(),annot=True,cmap='Spectral')
plt.show()

# %%
# Lets scale dataset for removing biasness

from sklearn.preprocessing import StandardScaler

# %%
st=StandardScaler()

# %%
x=pd.DataFrame(st.fit_transform(x),columns=x.columns)
x
# Out:
#        PH-121    HS-101    CY-105  HS-105/12    MT-111    CS-105    CS-106  \
# 0    0.400402  1.770900  1.722261   0.549869  1.374222  2.657832  1.790004
# 1   -1.242052  1.411559  2.397448   1.488043  0.369509  1.173242  1.790004
# 2   -1.242052 -0.744483 -0.978490   0.237145  0.034605 -1.053643  0.322008
# 3    1.714365  0.692879  2.397448   1.488043  1.709126 -0.311348  2.157003
# 4   -0.585070 -1.103823 -0.303302  -0.075580 -1.305012 -1.053643 -0.778989
# ..        ...       ...       ...        ...       ...       ...       ...
# 566 -0.256579 -1.822504 -0.978490  -0.701029 -0.970108 -1.053643 -0.778989
# 567 -0.913561 -1.822504 -0.978490  -1.326478 -1.305012 -1.053643 -1.512987
# 568 -0.256579 -1.822504 -0.303302  -0.075580 -1.305012 -1.053643 -1.512987
# 569 -1.242052 -0.385142  2.059854  -1.326478  1.709126  2.657832  0.322008
# 570  0.728893  1.411559  2.059854   0.549869  0.704413  2.657832 -0.411990
#
# ...

# %%
# Lets use Variance Inflation Factor for checking Mullticollinearity 

from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif=pd.DataFrame()
vif["VIF Values"]=[variance_inflation_factor(x.values,i) for i in range (len(x.columns))]
vif['features']=x.columns
vif
# Out:
#     VIF Values   features
# 0     2.827608     PH-121
# 1     1.771294     HS-101
# 2     2.514966     CY-105
# 3     2.293035  HS-105/12
# 4     2.638921     MT-111
# 5     2.366597     CS-105
# 6     1.927701     CS-106
# 7     1.968027     EL-102
# 8     2.190768     EE-119
# 9     2.294552     ME-107
# 10    2.350875     CS-107
# 11    1.633210  HS-205/20
# 12    2.277248     MT-222
# 13    2.254361     EE-222
# 14    2.798314     MT-224
# 15    3.084264     CS-210
# 16    2.640904     CS-211
# 17    2.612616     CS-203
# 18    2.688396     CS-214
# 19    2.435192     EE-217
# 20    2.770283     CS-212
# 21    3.022915     CS-215
# 22    2.052599     MT-331
# 23    2.113301     EF-303
# 24    2.498852     HS-304
# 25    3.095874     CS-301
# 26    2.741509     CS-302
# 27    2.889101     TC-383
# 28    2.027056     MT-442
# 29    3.275353     EL-332
# 30    2.355677     CS-318
# 31    3.471549     CS-306
# 32    3.239651     CS-312
# 33    3.161398     CS-317
# ...

# %%
# There is very less Multicollinearti and the values in each column looks similar

# %% [markdown]
# # Modelling

# %%
# IMPORTING MACHINE LEARNING LIBRARIES
from sklearn.neighbors import KNeighborsRegressor  
from sklearn.tree import DecisionTreeRegressor 
from sklearn.linear_model import LogisticRegression  
from sklearn.ensemble import RandomForestRegressor 
from sklearn.tree import ExtraTreeRegressor
from sklearn.svm import SVR
from sklearn.linear_model import Lasso,Ridge
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=49)

# %%
print(x.shape,x_train.shape,x_test.shape)
# Out:
# (571, 41) (382, 41) (189, 41)

# %%
KNR=KNeighborsRegressor()
DTR=DecisionTreeRegressor()
RFR=RandomForestRegressor()
LS=Lasso()
RG=Ridge()

model=[KNR,DTR,RFR,LS,RG]

for m in model:
    m.fit(x_train,y_train)
    predm=m.predict(x_test)
    print("R_2_Score -->",m,r2_score(y_test,predm))
    print("Mean Squared Error -->",m,mean_squared_error(y_test,predm))
    print("Mean Absolute Error -->",m,mean_absolute_error(y_test,predm))
    print("Root Mean Squared Error -->",m,np.sqrt(mean_squared_error(y_test,predm)))
    print('\n')
# Out:
# R_2_Score --> KNeighborsRegressor() 0.8809909071277514
# Mean Squared Error --> KNeighborsRegressor() 0.046227060740740754
# Mean Absolute Error --> KNeighborsRegressor() 0.10325714285714287
# Root Mean Squared Error --> KNeighborsRegressor() 0.21500479236691622
#
#
# R_2_Score --> DecisionTreeRegressor() 0.6998837949742858
# Mean Squared Error --> DecisionTreeRegressor() 0.11657504232804232
# Mean Absolute Error --> DecisionTreeRegressor() 0.219021164021164
# Root Mean Squared Error --> DecisionTreeRegressor() 0.3414308748898411
#
#
# R_2_Score --> RandomForestRegressor() 0.8826344770392702
# Mean Squared Error --> RandomForestRegressor() 0.045588643924867764
# Mean Absolute Error --> RandomForestRegressor() 0.12039269841269844
# Root Mean Squared Error --> RandomForestRegressor() 0.2135149735378476
#
#
# R_2_Score --> Lasso() -0.010984493037982768
# Mean Squared Error --> Lasso() 0.39269975461271495
# Mean Absolute Error --> Lasso() 0.5284218122385663
# ...

# %%
# By Checking R2_Score Ridge and KNeighbour Regressor is our best model

# %%
# Lets reconfirm our model which is best by using Cross_Validation_Score

from sklearn .model_selection import cross_val_score

# %%
# Cross-validation for KNeighbors Regressor
scores = cross_val_score(KNR, x_train, y_train, cv=5)
print("Cross-validation scores --> KNR", scores)
print("Mean cross-validation score --> KNR", scores.mean())
print("Difference between R2 Score and CVS -->",(r2_score(y_test,predm)-scores.mean())*100)
print('\n')

# Cross-validation for Decision Tree Regressor
scores = cross_val_score(DTR, x_train, y_train, cv=5)
print("Cross-validation scores --> DTR", scores)
print("Mean cross-validation score --> DTR", scores.mean())
print("Difference between R2 Score and CVS -->",(r2_score(y_test,predm)-scores.mean())*100)
print('\n')


# Cross-validation for Random Forest Regressor
scores = cross_val_score(RFR, x_train, y_train, cv=5)
print("Cross-validation scores --> RFR", scores)
print("Mean cross-validation score --> RFR", scores.mean())
print("Difference between R2 Score and CVS -->",(r2_score(y_test,predm)-scores.mean())*100)
print('\n')

# Cross-validation for GaussianNB
scores = cross_val_score(LS, x_train, y_train, cv=5)
print("Cross-validation scores --> Lasso", scores)
print("Mean cross-validation score --> Lasso", scores.mean())
print("Difference between R2 Score and CVS -->",(r2_score(y_test,predm)-scores.mean())*100)
print('\n')

# Cross-validation for SVC
scores = cross_val_score(RG, x_train, y_train, cv=5)
print("Cross-validation scores --> Ridge", scores)
print("Mean cross-validation score --> Ridge", scores.mean())
print("Difference between R2 Score and CVS -->",(r2_score(y_test,predm)-scores.mean())*100)
print('\n')
# Out:
# Cross-validation scores --> KNR [0.90454527 0.85772554 0.90249889 0.95712256 0.88329273]
# Mean cross-validation score --> KNR 0.9010370006599293
# Difference between R2 Score and CVS --> -0.10324832702240938
#
#
# Cross-validation scores --> DTR [0.72810618 0.80722913 0.86993176 0.75623397 0.8516209 ]
# Mean cross-validation score --> DTR 0.802624387744981
# Difference between R2 Score and CVS --> 9.73801296447242
#
#
# Cross-validation scores --> RFR [0.90921214 0.87090658 0.93159271 0.96130706 0.93171179]
# Mean cross-validation score --> RFR 0.9209460539861885
# Difference between R2 Score and CVS --> -2.0941536596483235
#
#
# Cross-validation scores --> Lasso [-0.06974971 -0.00011518 -0.00481006 -0.01618751 -0.00261011]
# Mean cross-validation score --> Lasso -0.01869451485318798
# Difference between R2 Score and CVS --> 91.86990322428932
#
#
# Cross-validation scores --> Ridge [0.89398588 0.89070788 0.9137466  0.95943029 0.90851545]
# ...

# %%
# Ridge model is very best model among all these models

# %%
# Lets Hypertune Our mddel for better results using GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV

# %%
param={'alpha':[1e-15,1e-10,1e-2,1,5,10,20,35,50,100],
       'fit_intercept':[True,False],
      'max_iter':['None',50,100,150,175,200],
      'solver':['auto','svd','cholesky','lsqr','sag','saga'],
      'tol':[0.01,0.001,0.0001,0.00001,0.000001]
      }

# %%
Grid_search = GridSearchCV(Ridge(),param) 
Grid_search.fit(x_train, y_train) 
print(Grid_search.best_estimator_)
# Out:
# Ridge(alpha=100, max_iter=150, solver='sag', tol=0.01)

# %%
model=Ridge(alpha=100, max_iter=150, solver='sag', tol=0.01)

# %%
modell=model.fit(x_train,y_train)
predmodel=modell.predict(x_test)
print('R2_Score',r2_score(y_test,predmodel))
print('Mean_Squared_error -->',mean_squared_error(y_test,predmodel))
print('Mean_Absolute_Error -->',mean_absolute_error(y_test,predmodel))
# Out:
# R2_Score 0.9066674820908155
# Mean_Squared_error --> 0.03625343131642531
# Mean_Absolute_Error --> 0.08345487919002212

# %%
# Saving our model

# %%
import joblib

# %%
joblib.dump(predmodel,'StudenGrades.pkl')
# Out:
# ['StudenGrades.pkl']

# %%
model=joblib.load("StudenGrades.pkl")
prediction=modell.predict(x_test)
prediction
# Out:
# array([3.47467753, 3.74409658, 3.82538342, 2.25974075, 2.2989013 ,
#        2.89570261, 3.02594297, 2.71295688, 3.22846277, 2.86677734,
#        3.24467062, 3.19783297, 3.30818599, 3.58842171, 2.26648989,
#        3.92003347, 3.7265507 , 3.15196368, 3.60020624, 2.49270848,
#        2.86727528, 3.60544173, 2.86051578, 3.25720626, 2.71219129,
#        2.71335373, 3.40685894, 3.52220512, 2.31623055, 3.74072433,
#        3.19671808, 3.79166518, 3.65090224, 3.9035874 , 2.8627281 ,
#        2.88077083, 2.52012337, 3.24753813, 2.67796695, 1.84887719,
#        2.45608138, 2.48856359, 2.39406526, 2.69210033, 3.47208149,
#        2.71273185, 3.39946252, 2.72219465, 3.33777915, 2.7637415 ,
#        3.19016295, 3.14991582, 2.80691719, 3.41342946, 3.29725676,
#        3.54065878, 2.27949996, 2.07403853, 2.04388869, 3.90630449,
#        2.03749316, 2.61728808, 1.99021528, 3.33110772, 3.10618036,
#        3.94949498, 3.33761948, 3.89745552, 2.04350598, 2.61785818,
# ...

# %%
# Making data frame of Predicted and Original Dataframe

a=np.array(y_test)
df=pd.DataFrame()
df["Predicted"]=prediction
df["Original"]=a
df
# Out:
#      Predicted  Original
# 0     3.474678     3.437
# 1     3.744097     3.754
# 2     3.825383     3.769
# 3     2.259741     2.188
# 4     2.298901     2.378
# ..         ...       ...
# 184   2.964806     3.094
# 185   1.792869     1.768
# 186   2.238057     2.363
# 187   3.237598     3.253
# 188   3.118358     3.179
#
# [189 rows x 2 columns]

# %%
# We can check our model by putting values into the Input data

inputdata=(int(input('Enput Your Values')))
# Changing input data to a numpy array
input_data_as_numpy_array=np.asarray(inputdata)  
#Reshape the array
input_data_reshaped=input_data_as_numpy_array.reshape(1,-1)
prediction2=model.predict(input_data_reshaped)

# %%
joblib.dump(prediction2,'Student_Prediction.pkl')

# %%
# Lets Take Summary what we have done - 

""" 1. Importing Library
2. Importing Dataset
3. Checking Shape of Dataset
4. Checking Null Values
5. Checking Info of Dataset
6. Checking Null Values
7. Filling Null Values Using Mode Tehniques
8. Seprating Dataset 
    x = Independent Variable
    y = Target Variable
9. Checking Unique Values
10. Using Label Encoder to make Categorical Values into Numerical Value
11. Checking Statistics of Dataset
12. Checking Outliers
13. Checking Correlation
14. Using Standard Scaling to removing biasness
15. Checking Variance Inflation Factor
16. Importing Machine Learning Libraries
17. Modelling the model
18. Checking Cross Validation Score
19. Hyper tuning The model
20. Making Final Model
21. Make Prediction 
23. Saving The File using JobLib
"""

# %% [markdown]
# THANKYOU
